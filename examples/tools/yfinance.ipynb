# %%
# !uv pip install -q langgraph langchain-openai langchain-anthropic langchain-google-genai langchain-groq langchain-xai deepagents
# Out:
# Running cells with '.venv (Python 3.12.8)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ryaneggz/ruska-ai/deployments/orchestra/backend/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print(os.environ["OPENAI_API_KEY"])
